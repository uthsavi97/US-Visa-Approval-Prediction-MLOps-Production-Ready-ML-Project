# %% [markdown]
# <!-- ===================== TITLE ===================== -->
# <h1 style="color:#0B3C5D; text-align:center;">
# 🇺🇸 US Visa Prediction Project
# </h1>
#
# <hr style="border:1px solid #328CC1;">
#
# <!-- ===================== LIFE CYCLE ===================== -->
# <h2 style="color:#1F7A8C;">🔄 Life Cycle of Machine Learning Project</h2>
#
# <ul style="color:#34495E; font-size:16px;">
#   <li>📌 <b>Understanding the Problem Statement</b></li>
#   <li>📊 <b>Data Collection</b></li>
#   <li>🔍 <b>Exploratory Data Analysis (EDA)</b></li>
#   <li>🧹 <b>Data Cleaning</b></li>
#   <li>⚙️ <b>Data Pre-Processing</b></li>
#   <li>🤖 <b>Model Training</b></li>
#   <li>🏆 <b>Choosing the Best Model</b></li>
# </ul>
#
# <hr style="border:1px dashed #A1C6EA;">
#
# <!-- ===================== ABOUT ===================== -->
# <h2 style="color:#1F7A8C;">📘 About the Project</h2>
#
# <p style="color:#2C3E50; font-size:15px; line-height:1.6;">
# The <b>Immigration and Nationality Act (INA)</b> of the United States permits foreign workers
# to come to the country on either a <b>temporary</b> or <b>permanent</b> basis.
# The act also protects U.S. workers by ensuring fair hiring practices and maintaining
# requirements when employers recruit foreign talent.
# </p>
#
# <p style="color:#2C3E50; font-size:15px; line-height:1.6;">
# These immigration programs are administered by the
# <b>Office of Foreign Labor Certification (OFLC)</b>.
# </p>
#
# <hr style="border:1px solid #328CC1;">
#
# <!-- ===================== PROBLEM STATEMENT ===================== -->
# <h2 style="color:#1F7A8C;">📌 1. Problem Statement</h2>
#
# <p style="color:#2C3E50; font-size:15px; line-height:1.6;">
# The <b>OFLC</b> processes job certification applications from employers
# seeking to bring foreign workers to the United States.
# </p>
#
# <p style="color:#2C3E50; font-size:15px; line-height:1.6;">
# In recent years, the number of applications has increased significantly.
# To handle this large volume efficiently, the OFLC requires
# <b>Machine Learning models</b> to help shortlist visa applicants
# based on historical data.
# </p>
#
# <p style="color:#2C3E50; font-size:15px; line-height:1.6;">
# In this project, we build a <b style="color:#27AE60;">Classification Model</b> that:
# </p>
#
# <ul style="color:#34495E; font-size:15px;">
#   <li>✅ Predicts whether a visa will be <b>Approved</b> or <b>Denied</b></li>
#   <li>📌 Recommends suitable applicant profiles</li>
#   <li>📊 Identifies key factors influencing visa decisions</li>
# </ul>
#
# <hr style="border:1px dashed #A1C6EA;">
#
# <!-- ===================== DATA COLLECTION ===================== -->
# <h2 style="color:#1F7A8C;">📊 2. Data Collection</h2>
#
# <p style="color:#2C3E50; font-size:15px; line-height:1.6;">
# The dataset used in this project is sourced from the
# <b>Office of Foreign Labor Certification (OFLC)</b>.
# </p>
#
# <ul style="color:#34495E; font-size:15px;">
#   <li>📄 <b>Total Rows:</b> 25,480</li>
#   <li>📌 <b>Total Columns:</b> 12</li>
#   <li>🔗 <b>Dataset Link:</b>
#     <a href="https://www.kaggle.com/datasets/moro23/easyvisa-dataset" target="_blank" style="color:#2980B9;">
#       Kaggle – EasyVisa Dataset
#     </a>
#   </li>
# </ul>
#
# <hr style="border:1px solid #328CC1;">
#
# <!-- ===================== IMPORT SECTION ===================== -->
# <h2 style="color:#1F7A8C;">📦 2.1 Import Data and Required Packages</h2>
#
# <p style="color:#2C3E50; font-size:15px;">
# The following Python libraries are used for data analysis, visualization,
# and model development:
# </p>
#
# <ul style="color:#34495E; font-size:15px;">
#   <li>🐼 <b>Pandas</b> – Data manipulation</li>
#   <li>🔢 <b>NumPy</b> – Numerical computations</li>
#   <li>📈 <b>Matplotlib</b> – Data visualization</li>
#   <li>📊 <b>Seaborn</b> – Statistical plotting</li>
#   <li>⚠️ <b>Warnings</b> – Handling warning messages</li>
# </ul>
